# %%
import pandas as pd
import seaborn as sns
import os
import analysis

# %%
analyser = analysis.Analyser("perf")
all_data = analyser.get_data()
all_data
# Out:
# loading from ../bench/perf
# processing a76ea53a3d1059e42d846046e838a7ea9045f226a92a9acfc0bee676fab38c91
# processing b9ef1c01f6d44f990218904fd89557d112bd6d6408979f102600d8d6c81665b9
# processing 56ba3f5f6a73de6c4f0a5a3ea5f0ff021ff1ad60deb6f1ef51b0a7edf1281597
# processing 06943fb844d92402a520d6ec9c9ea7ed0ea75a6b2269904fd17fec55b213d03d
# processing 0d9b8bd9a2d5dcd7ba5af666aa6904485d3d4fe3537e3e2f5888b2ffe65d2e39
# processing 2646dfd817d566e943ec5b9a1adf123fad36e7eb0326041954e98000666c7a02
#                      path  status     start_ms        end_ms  latency_ms  \
# 0            /v3/kv/range     200      0.00000     53.966684   53.966684
# 1            /v3/kv/range     200     54.00450    141.178435   87.173935
# 2            /v3/kv/range     200    141.22800    229.003164   87.775164
# 3            /v3/kv/range     200    229.05775    316.933060   87.875310
# 4            /v3/kv/range     200    316.97725    405.042540   88.065290
# ...                   ...     ...          ...           ...         ...
# 1595  /v3/kv/delete_range     200  17414.32250  17458.429379   44.106879
# 1596  /v3/kv/delete_range     200  17458.45925  17502.347566   43.888316
# 1597  /v3/kv/delete_range     200  17502.37825  17546.274664   43.896414
# 1598  /v3/kv/delete_range     200  17546.30700  17590.261790   43.954790
# 1599  /v3/kv/delete_range     200  17590.29325  17634.404281   44.111031
#
#      store  port   tls    sgx  nodes  worker_threads  sig_tx_interval  \
# 0     lskv  8000  True  False      1               0             5000
# 1     lskv  8000  True  False      1               0             5000
# 2     lskv  8000  True  False      1               0             5000
# 3     lskv  8000  True  False      1               0             5000
# 4     lskv  8000  True  False      1               0             5000
# ...    ...   ...   ...    ...    ...             ...              ...
# 1595  lskv  8000  True  False      1               0             5000
# 1596  lskv  8000  True  False      1               0             5000
# 1597  lskv  8000  True  False      1               0             5000
# 1598  lskv  8000  True  False      1               0             5000
# 1599  lskv  8000  True  False      1               0             5000
#
#       sig_ms_interval ledger_chunk_bytes  snapshot_tx_interval  http_version
# 0                 100               20KB                    10             2
# 1                 100               20KB                    10             2
# 2                 100               20KB                    10             2
# 3                 100               20KB                    10             2
# 4                 100               20KB                    10             2
# ...               ...                ...                   ...           ...
# 1595              100               20KB                    10             1
# 1596              100               20KB                    10             1
# 1597              100               20KB                    10             1
# 1598              100               20KB                    10             1
# 1599              100               20KB                    10             1
#
# [1600 rows x 16 columns]

# %%
plot_data = all_data.copy(deep=False)
analyser.plot_scatter(plot_data,col="nodes", row="http_version")
# Out:
# /home/t-ajeffery/projects/lskv/benchmark/analysis.py:348: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   variant_column = pd.Series()

# %%
plot_data = all_data.copy(deep=False)
analyser.plot_ecdf(plot_data,col="nodes", row="http_version")
# Out:
# /home/t-ajeffery/projects/lskv/benchmark/analysis.py:348: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   variant_column = pd.Series()
